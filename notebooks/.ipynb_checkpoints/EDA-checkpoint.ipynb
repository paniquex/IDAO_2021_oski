# %%
import sys
sys.path.append("../src")

# %%
from paths import *

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Train .csv

# %%
train_tp = pd.read_csv(f"{DATA_ROOT}/train_tp.csv")

# %%
train_tp
# Out:
#      recording_id  species_id  songtype_id    t_min     f_min    t_max  \
# 0       003bec244          14            1  44.5440  2531.250  45.1307
# 1       006ab765f          23            1  39.9615  7235.160  46.0452
# 2       007f87ba2          12            1  39.1360   562.500  42.2720
# 3       0099c367b          17            4  51.4206  1464.260  55.1996
# 4       009b760e6          10            1  50.0854   947.461  52.5293
# ...           ...         ...          ...      ...       ...      ...
# 1211    fe8d9ac40          13            1  53.4720    93.750  54.0960
# 1212    fea6b438a           4            1  43.5787  2531.250  45.7653
# 1213    ff2eb9ce5           0            1  15.2267  5906.250  16.0213
# 1214    ffb8d8391           5            1  14.3467  4781.250  16.6987
# 1215    ffb9a7b9a          18            1  40.3200  3187.500  41.0133
#
#          f_max
# 0      5531.25
# 1     11283.40
# 2      3281.25
# 3      4565.04
# 4     10852.70
# ...        ...
# ...

# %%
tp_len = train_tp.t_max - train_tp.t_min

# %%
plt.hist(tp_len)
# Out:
# (array([289., 234., 253., 131., 102.,  50.,  17.,  50.,  40.,  50.]),
#  array([0.272  , 1.03719, 1.80238, 2.56757, 3.33276, 4.09795, 4.86314,
#         5.62833, 6.39352, 7.15871, 7.9239 ]),
#  <BarContainer object of 10 artists>)

# %%
np.mean(tp_len)
# Out:
# 2.537118585526316

# %%
np.median(tp_len)
# Out:
# 1.8560000000000016

# %%
train_fp = pd.read_csv(f"{DATA_ROOT}/train_fp.csv")

# %%
train_fp
# Out:
#      recording_id  species_id  songtype_id    t_min       f_min    t_max  \
# 0       00204008d          21            1  13.8400   3281.2500  14.9333
# 1       00204008d           8            1  24.4960   3750.0000  28.6187
# 2       00204008d           4            1  15.0027   2343.7500  16.8587
# 3       003b04435          22            1  43.2533  10687.5000  44.8587
# 4       003b04435          23            1   9.1254   7235.1562  15.2091
# ...           ...         ...          ...      ...         ...      ...
# 7776    ffd88cd84          14            1   3.2000   2531.2500   3.7867
# 7777    ffebe7313           1            1  35.2000   3843.7500  36.0960
# 7778    fff163132          17            4  22.5547   1312.5000  25.0880
# 7779    fff163132          14            1  37.0827   2531.2500  37.6693
# 7780    fffb79246           6            1   8.3573    562.5000  10.5013
#
#            f_max
# 0      4125.0000
# 1      5531.2500
# 2      4218.7500
# 3     13687.5000
# ...

# %%
fp_len = train_fp.t_max - train_fp.t_min

# %%
plt.hist(fp_len)
# Out:
# (array([1260., 1775., 1672., 1026.,  848.,  300.,    0.,  300.,  300.,
#          300.]),
#  array([0.272  , 1.03719, 1.80238, 2.56757, 3.33276, 4.09795, 4.86314,
#         5.62833, 6.39352, 7.15871, 7.9239 ]),
#  <BarContainer object of 10 artists>)

# %%
np.mean(fp_len)
# Out:
# 2.6400814034185838

# %%
np.median(fp_len)
# Out:
# 2.144000000000002

# %% [markdown]
# # Sample submission

# %%
sample_submission = pd.read_csv(f"{DATA_ROOT}/sample_submission.csv")

# %%
sample_submission
# Out:
#      recording_id   s0   s1   s2   s3   s4   s5   s6   s7   s8  ...  s14  s15  \
# 0       000316da7  0.5  0.5  0.5  0.5  0.5  0.5  0.5  0.5  0.5  ...  0.5  0.5
# 1       003bc2cb2  0.5  0.5  0.5  0.5  0.5  0.5  0.5  0.5  0.5  ...  0.5  0.5
# 2       0061c037e  0.5  0.5  0.5  0.5  0.5  0.5  0.5  0.5  0.5  ...  0.5  0.5
# 3       010eb14d3  0.5  0.5  0.5  0.5  0.5  0.5  0.5  0.5  0.5  ...  0.5  0.5
# 4       011318064  0.5  0.5  0.5  0.5  0.5  0.5  0.5  0.5  0.5  ...  0.5  0.5
# ...           ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 1987    ff68f3ac3  0.5  0.5  0.5  0.5  0.5  0.5  0.5  0.5  0.5  ...  0.5  0.5
# 1988    ff973e852  0.5  0.5  0.5  0.5  0.5  0.5  0.5  0.5  0.5  ...  0.5  0.5
# 1989    ffa5cf6d6  0.5  0.5  0.5  0.5  0.5  0.5  0.5  0.5  0.5  ...  0.5  0.5
# 1990    ffa88cbb8  0.5  0.5  0.5  0.5  0.5  0.5  0.5  0.5  0.5  ...  0.5  0.5
# 1991    ffda5d7b3  0.5  0.5  0.5  0.5  0.5  0.5  0.5  0.5  0.5  ...  0.5  0.5
#
# ...
